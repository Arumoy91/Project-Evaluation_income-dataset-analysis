# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('adultdata.csv')  # Reading the data files
df
# Out:
#        age          workclass  fnlwgt    education  education.num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital.status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.info() # finding the index,data-type,& memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.tail(10)
# Out:
#        age      workclass  fnlwgt      education  education.num  \
# 32551   32        Private   34066           10th              6
# 32552   43        Private   84661      Assoc-voc             11
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital.status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
cat_col = df.dtypes[df.dtypes == 'object']
num_col = df.dtypes[df.dtypes != 'object']

# %%
df.shape  #finding the data shape
# Out:
# (32561, 15)

# %%
df['income'] = df['income'].apply(lambda x: 1 if x==' >50K' else 0)

# %%
df.replace(' ?', np.nan, inplace=True)

# %%
df.fillna(' 0', inplace=True)

# %%
for col in df.columns:
    if type(df[col][0]) == str:
        print("Working on " + col)
        df[col] = df[col].apply(lambda val: val.replace(" ",""))
# Out:
# Working on workclass
# Working on education
# Working on marital.status
# Working on occupation
# Working on relationship
# Working on race
# Working on sex
# Working on native.country

# %%
df.drop('workclass',axis=1,inplace=True)

# %%
df.drop('marital.status',axis=1,inplace=True)  #dropping unnecessary data from the dataset.
df.drop('occupation',axis=1,inplace=True)
df.drop('relationship',axis=1,inplace=True)
df.drop('race',axis=1,inplace=True)
df.drop('native.country',axis=1,inplace=True)

# %%
df.drop('education', axis=1,inplace=True)

# %%
df.head()
# Out:
#    age  fnlwgt  education.num     sex  capital.gain  capital.loss  \
# 0   39   77516             13    Male          2174             0
# 1   50   83311             13    Male             0             0
# 2   38  215646              9    Male             0             0
# 3   53  234721              7    Male             0             0
# 4   28  338409             13  Female             0             0
#
#    hours.per.week  income
# 0              40       0
# 1              13       0
# 2              40       0
# 3              40       0
# 4              40       0

# %%
df.drop('sex', axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 0    39   77516             13          2174             0              40
# 1    50   83311             13             0             0              13
# 2    38  215646              9             0             0              40
# 3    53  234721              7             0             0              40
# 4    28  338409             13             0             0              40
# 5    37  284582             14             0             0              40
# 6    49  160187              5             0             0              16
# 7    52  209642              9             0             0              45
# 8    31   45781             14         14084             0              50
# 9    42  159449             13          5178             0              40
# 10   37  280464             10             0             0              80
# ...

# %%
plt.hist(df['age']);

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
# income          0.234037 -0.009463       0.335154      0.223329      0.150526
#
#                 hours.per.week    income
# age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education.num         0.148123  0.335154
# capital.gain          0.078409  0.223329
# capital.loss          0.054256  0.150526
# hours.per.week        1.000000  0.229689
# income                0.229689  1.000000

# %%
sns.heatmap(df.corr(),annot = True);

# %%
sns.factorplot(x="age",y="income",data=df,kind="bar", size = 20)
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df)

# %%
sns.factorplot(x="hours.per.week",y="income",data=df,kind="bar", size = 20)
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(x="education.num",y="income",data=df,kind="bar", size = 10)
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #Finding the best Suitable model for this dataset

# %%
cols = ['age','hours.per.week', 'income']
for col in cat_col.index:
    if col in cols:
        print(df[df['age'] == 90][col].value_counts())
    else:
        continue
# Out:
# 0    35
# 1     8
# Name: income, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x = np.array(df.drop(['income'], 1))
y = np.array(df['income'])
y = np.array(df['income'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=12)

# %%
lr=LogisticRegression()

# %%
lr=lr.fit(x_train, y_train)

# %%
lr.score(x_train,y_train)
# Out:
# 0.7991784398034398

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[4726  202]
#  [1157  428]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87      4928
#            1       0.68      0.27      0.39      1585
#
#     accuracy                           0.79      6513
#    macro avg       0.74      0.61      0.63      6513
# weighted avg       0.77      0.79      0.76      6513

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
lm = LinearRegression()

# %%
lm = lm.fit(x_train, y_train)

# %%
lm.score(x_train, y_train)
# Out:
# 0.2276225611578305

# %%
lm.coef_
# Out:
# array([6.07447969e-03, 6.95024567e-08, 4.59562124e-02, 9.46861241e-06,
#        1.24809880e-04, 5.29559416e-03])

# %%
y_lm = lm.predict(x_test)

# %%
y_lm
# Out:
# array([0.99938091, 0.36043512, 0.07452639, ..., 0.48482641, 0.04854205,
#        0.21346921])

# %%
from sklearn import preprocessing, neighbors
from sklearn.metrics import accuracy_score

# %%
clf = neighbors.KNeighborsClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
k_pr = clf.predict(x_test)

# %%
print(confusion_matrix(y_test,k_pr))
# Out:
# [[4515  413]
#  [1066  519]]

# %%
KA = accuracy_score(y_test, k_pr)

# %%
KA
# Out:
# 0.7729157070474436

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import metrics

# %%
clf_tr = DecisionTreeClassifier( max_depth = 8 )

# %%
clf_tr.fit( x_train, y_train )
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
tree_predict = clf_tr.predict( x_test )

# %%
metrics.accuracy_score( y_test, tree_predict )
# Out:
# 0.831260555811454

# %%
print(confusion_matrix(y_test,tree_predict))
# Out:
# [[4723  205]
#  [ 894  691]]

# %%
print(classification_report(y_test,tree_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      4928
#            1       0.77      0.44      0.56      1585
#
#     accuracy                           0.83      6513
#    macro avg       0.81      0.70      0.73      6513
# weighted avg       0.82      0.83      0.81      6513

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=2)

# %%
k_means.fit(x_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
k_labels = k_means.labels_

# %%
labelpre = k_means.predict(x_test)

# %%
print(confusion_matrix(y_test,labelpre))
# Out:
# [[1263 3665]
#  [ 397 1188]]

# %%
print(classification_report(y_test,labelpre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.26      0.38      4928
#            1       0.24      0.75      0.37      1585
#
#     accuracy                           0.38      6513
#    macro avg       0.50      0.50      0.38      6513
# weighted avg       0.64      0.38      0.38      6513

# %%
KA = accuracy_score(y_test, labelpre)

# %%
KA
# Out:
# 0.3763242745278673

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
model = GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
naive_pre= model.predict(x_test)

# %%
naive_pre
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
print(confusion_matrix(y_test,naive_pre))
# Out:
# [[4654  274]
#  [1089  496]]

# %%
print(classification_report(y_test,naive_pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      4928
#            1       0.64      0.31      0.42      1585
#
#     accuracy                           0.79      6513
#    macro avg       0.73      0.63      0.65      6513
# weighted avg       0.77      0.79      0.76      6513

# %%
NB = accuracy_score(y_test, naive_pre)

# %%
NB
# Out:
# 0.7907262398280362

# %% [markdown]
# Conclusion: We have used several classification & other techniques to find out whether a person makes over a 50 k a year and the decision tree model yields to the best prediction result for this datset.
